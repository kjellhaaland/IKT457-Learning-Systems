# %%
# !pip install keras
# !pip install wrapt
# !pip install tensorflow
# !pip install tmu
# !pip install opencv-python

# %%
import numpy as np
import cv2

import matplotlib.pyplot as plt
from keras.datasets import cifar10

# %%
import cv2
from matplotlib import pyplot as plt
from keras.datasets import cifar10

# Load CIFAR-10 dataset
(X_train_org, Y_train_org), (X_test_org, Y_test_org) = cifar10.load_data()

X_train = np.copy(X_train_org)
X_test = np.copy(X_test_org)

Y_train=Y_train_org.reshape(Y_train_org.shape[0])
Y_test=Y_test_org.reshape(Y_test_org.shape[0])

# Function to preprocess images using Canny edge detection
def preprocess_images(images):
    processed_images = []
    
    for image in images:
        #image = cv2.GaussianBlur(image, (3, 3), 0.5)
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        thresh = cv2.adaptiveThreshold(gray_image, 1, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)
        processed_images.append(thresh)
        
    return np.array(processed_images)

X_train_processed = preprocess_images(X_train)
X_test_processed = preprocess_images(X_test)

# Display the images
plt.figure(figsize=(15, 12))

for i in range(10):
    plt.subplot(4, 5, i + 1)
    plt.imshow(X_test[i])
    plt.title('Original Image {}'.format(i + 1))
    plt.axis('off')

    plt.subplot(4, 5, i + 11)
    plt.imshow(X_test_processed[i], cmap='gray')
    plt.title('Processed Image {}'.format(i + 1))
    plt.axis('off')

plt.savefig('inverse_thresh.png')
plt.show()

# %%
print(X_train.shape)
print(X_train_processed.shape)

#X_train = X_train_processed
#X_test = X_test_processed
# Out:
# (50000, 32, 32, 3)
# (50000, 32, 32)

# %%
from tmu.models.classification.vanilla_classifier import TMClassifier
from time import time

num_clauses=2000
T=500
s=10.0
patch_size=16
max_included_literals=32
weighted_clauses=True

tm = TMClassifier(
    number_of_clauses=num_clauses,
    T=T,
    s=s,
    max_included_literals=max_included_literals,
    platform="GPU",
    weighted_clauses=True,
    patch_dim=(patch_size, patch_size)
)

epochs = 100

for epoch in range(epochs):
        start_training = time()
        tm.fit(X_train_processed, Y_train)
        stop_training = time()

        start_testing = time()
        Y_test_predicted, Y_test_scores = tm.predict(X_test_processed, return_class_sums=True)
        stop_testing = time()

        result_test = 100*(Y_test_scores.argmax(axis=1) == Y_test).mean()

        print("#%d Accuracy: %.2f%% Training: %.2fs Testing: %.2fs" % (epoch+1, result_test, stop_training-start_training, stop_testing-start_testing))

        np.savetxt("CIFAR10ThresInvBlur_%d_%d_%d_%.1f_%d_%d_%d.txt" % (epoch+1, num_clauses, T, s, patch_size, max_included_literals, weighted_clauses), Y_test_scores, delimiter=',')
# Out:
# 2023-12-10 18:18:21,306 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:21,308 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:21,309 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:21,311 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:21,464 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:21,466 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:21,467 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:21,469 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:21,615 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:21,617 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:21,620 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:21,622 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:21,769 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:21,771 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:21,773 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:21,775 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:21,922 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:21,924 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:21,925 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:21,927 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:22,073 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:22,075 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:22,077 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:22,079 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:22,229 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:22,231 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:22,233 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:22,234 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:22,382 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:22,384 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:22,385 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:22,387 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:22,537 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:22,538 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:22,539 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:22,541 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# 2023-12-10 18:18:22,693 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/9f17b3fbf8b1682fbb779952d634532cbe458e44.ptx'.
# 2023-12-10 18:18:22,695 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/fbdc3b0da45d49a13d8b05b7a93918512733d356.ptx'.
# 2023-12-10 18:18:22,697 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/8766837ea3e9fb0421659f32113def476ea530a6.ptx'.
# 2023-12-10 18:18:22,700 - tmu.clause_bank.clause_bank_cuda - INFO - Loading compiled CUDA module from '/tmp/tm_kernels/f9989a410747fcc8100763dbca90aec43b28afba.ptx'.
# #1 Accuracy: 35.22% Training: 139.54s Testing: 41.56s
# #2 Accuracy: 39.02% Training: 131.02s Testing: 41.89s
# #3 Accuracy: 41.87% Training: 127.97s Testing: 42.11s
# #4 Accuracy: 39.08% Training: 126.92s Testing: 42.25s
# #5 Accuracy: 41.27% Training: 127.43s Testing: 42.58s
# #6 Accuracy: 41.98% Training: 124.06s Testing: 42.79s
# #7 Accuracy: 45.20% Training: 123.53s Testing: 42.37s
# #8 Accuracy: 45.51% Training: 121.71s Testing: 42.41s
# #9 Accuracy: 45.27% Training: 120.28s Testing: 42.56s
# #10 Accuracy: 43.99% Training: 121.80s Testing: 42.85s
# #11 Accuracy: 44.73% Training: 121.72s Testing: 42.99s
# #12 Accuracy: 45.77% Training: 119.77s Testing: 43.42s
# #13 Accuracy: 45.62% Training: 118.72s Testing: 42.98s
# #14 Accuracy: 46.80% Training: 117.27s Testing: 42.94s
# #15 Accuracy: 45.15% Training: 116.12s Testing: 42.84s
# #16 Accuracy: 46.32% Training: 115.44s Testing: 43.25s
# #17 Accuracy: 46.41% Training: 115.02s Testing: 42.91s
# #18 Accuracy: 47.19% Training: 114.17s Testing: 42.86s
# #19 Accuracy: 46.85% Training: 113.53s Testing: 43.13s
# #20 Accuracy: 46.84% Training: 112.76s Testing: 42.87s
# #21 Accuracy: 46.71% Training: 113.19s Testing: 43.56s
# #22 Accuracy: 47.06% Training: 112.55s Testing: 43.15s
# #23 Accuracy: 47.79% Training: 111.98s Testing: 42.97s
# #24 Accuracy: 48.16% Training: 110.80s Testing: 42.77s
# #25 Accuracy: 48.17% Training: 110.15s Testing: 42.93s
# #26 Accuracy: 46.36% Training: 113.85s Testing: 43.37s
# #27 Accuracy: 47.72% Training: 112.02s Testing: 43.46s
# #28 Accuracy: 47.63% Training: 111.85s Testing: 43.46s
# #29 Accuracy: 47.08% Training: 111.21s Testing: 43.68s
# #30 Accuracy: 47.05% Training: 111.47s Testing: 43.81s
# #31 Accuracy: 47.94% Training: 108.79s Testing: 43.23s
# #32 Accuracy: 47.83% Training: 108.56s Testing: 43.32s
# #33 Accuracy: 47.82% Training: 108.08s Testing: 43.24s
# #34 Accuracy: 48.07% Training: 107.54s Testing: 43.35s
# #35 Accuracy: 48.94% Training: 106.97s Testing: 43.54s
# #36 Accuracy: 48.41% Training: 107.30s Testing: 43.25s
# #37 Accuracy: 48.50% Training: 106.59s Testing: 43.23s
# #38 Accuracy: 47.50% Training: 106.44s Testing: 43.50s
# #39 Accuracy: 48.60% Training: 106.39s Testing: 43.19s
# #40 Accuracy: 48.73% Training: 105.50s Testing: 43.23s
# #41 Accuracy: 47.96% Training: 105.51s Testing: 43.14s
# #42 Accuracy: 48.11% Training: 105.33s Testing: 43.31s
# #43 Accuracy: 47.73% Training: 105.35s Testing: 43.19s
# #44 Accuracy: 47.37% Training: 105.59s Testing: 43.27s
# #45 Accuracy: 48.25% Training: 104.70s Testing: 43.20s
# #46 Accuracy: 48.45% Training: 104.60s Testing: 43.17s
# #47 Accuracy: 47.40% Training: 104.05s Testing: 43.28s
# #48 Accuracy: 48.08% Training: 104.10s Testing: 43.21s
# #49 Accuracy: 48.18% Training: 103.96s Testing: 43.14s
# #50 Accuracy: 48.47% Training: 103.61s Testing: 43.22s
# #51 Accuracy: 48.99% Training: 103.52s Testing: 43.22s
# #52 Accuracy: 48.57% Training: 103.57s Testing: 43.17s
# #53 Accuracy: 49.13% Training: 103.25s Testing: 43.54s
# #54 Accuracy: 48.30% Training: 103.20s Testing: 43.28s
# #55 Accuracy: 47.92% Training: 103.29s Testing: 43.27s
# #56 Accuracy: 48.16% Training: 102.95s Testing: 43.48s
# #57 Accuracy: 47.86% Training: 102.82s Testing: 43.22s
# #58 Accuracy: 48.96% Training: 102.41s Testing: 43.19s
# #59 Accuracy: 48.20% Training: 102.47s Testing: 43.30s
# #60 Accuracy: 48.30% Training: 102.14s Testing: 43.21s
# #61 Accuracy: 48.59% Training: 102.06s Testing: 43.22s
# #62 Accuracy: 47.83% Training: 102.43s Testing: 43.21s
# #63 Accuracy: 48.88% Training: 102.47s Testing: 43.31s
# #64 Accuracy: 48.94% Training: 102.49s Testing: 43.44s
# #65 Accuracy: 49.31% Training: 101.96s Testing: 43.38s
# #66 Accuracy: 48.78% Training: 101.81s Testing: 43.25s
# #67 Accuracy: 48.40% Training: 101.52s Testing: 43.34s
# #68 Accuracy: 48.48% Training: 101.47s Testing: 43.24s
# #69 Accuracy: 49.11% Training: 101.58s Testing: 43.36s
# #70 Accuracy: 48.37% Training: 101.34s Testing: 43.39s
# #71 Accuracy: 48.49% Training: 101.56s Testing: 43.50s
# #72 Accuracy: 48.78% Training: 103.50s Testing: 44.21s
# #73 Accuracy: 48.72% Training: 104.27s Testing: 43.81s
# #74 Accuracy: 48.95% Training: 100.96s Testing: 43.39s
# #75 Accuracy: 48.78% Training: 101.25s Testing: 43.45s
# #76 Accuracy: 49.04% Training: 101.30s Testing: 43.36s
# #77 Accuracy: 47.93% Training: 101.35s Testing: 43.40s
# #78 Accuracy: 48.78% Training: 101.49s Testing: 43.41s
# #79 Accuracy: 49.28% Training: 100.89s Testing: 43.60s
# #80 Accuracy: 48.61% Training: 100.86s Testing: 43.44s
# #81 Accuracy: 48.31% Training: 101.18s Testing: 43.38s
# #82 Accuracy: 49.36% Training: 100.85s Testing: 43.52s
# #83 Accuracy: 49.62% Training: 100.88s Testing: 43.52s
# #84 Accuracy: 49.29% Training: 100.69s Testing: 43.42s
# #85 Accuracy: 49.43% Training: 100.92s Testing: 43.45s
# #86 Accuracy: 48.75% Training: 100.91s Testing: 43.48s
# #87 Accuracy: 49.16% Training: 100.61s Testing: 43.48s
# #88 Accuracy: 48.02% Training: 100.94s Testing: 43.39s
# #89 Accuracy: 48.81% Training: 100.45s Testing: 43.43s
# #90 Accuracy: 48.96% Training: 100.34s Testing: 43.64s
# #91 Accuracy: 48.96% Training: 100.48s Testing: 43.29s
# #92 Accuracy: 49.77% Training: 100.60s Testing: 43.48s
# #93 Accuracy: 48.75% Training: 100.36s Testing: 43.46s
# #94 Accuracy: 49.44% Training: 100.29s Testing: 43.44s
# #95 Accuracy: 49.10% Training: 100.27s Testing: 43.73s
# #96 Accuracy: 48.66% Training: 100.39s Testing: 43.56s
# #97 Accuracy: 48.80% Training: 100.38s Testing: 43.41s
# #98 Accuracy: 48.93% Training: 100.37s Testing: 43.45s
# #99 Accuracy: 49.11% Training: 100.36s Testing: 43.50s
# #100 Accuracy: 49.08% Training: 100.57s Testing: 43.52s
